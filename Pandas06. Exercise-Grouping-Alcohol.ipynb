# %% [markdown]
# # Ex - GroupBy

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called drinks.

# %%
drinks=pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/drinks.csv', sep=',')
drinks
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %% [markdown]
# ### Step 4. Which continent drinks more beer on average?

# %%
bd=drinks.groupby(['continent'])
sb=bd.beer_servings.mean()
[sb]
# Out:
# [continent
#  AF     61.471698
#  AS     37.045455
#  EU    193.777778
#  OC     89.687500
#  SA    175.083333
#  Name: beer_servings, dtype: float64]

# %% [markdown]
# ### Step 5. For each continent print the statistics for wine consumption.

# %%
drinks.groupby(['continent']).wine_servings.describe()
# Out:
#            count        mean        std  min   25%    50%     75%    max
# continent
# AF          53.0   16.264151  38.846419  0.0   1.0    2.0   13.00  233.0
# AS          44.0    9.068182  21.667034  0.0   0.0    1.0    8.00  123.0
# EU          45.0  142.222222  97.421738  0.0  59.0  128.0  195.00  370.0
# OC          16.0   35.625000  64.555790  0.0   1.0    8.5   23.25  212.0
# SA          12.0   62.416667  88.620189  1.0   3.0   12.0   98.50  221.0

# %% [markdown]
# ### Step 6. Print the mean alcohol consumption per continent for every column

# %%
pd.pivot_table(drinks,index=['continent','country'], values=['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol'],aggfunc=['mean'])
# Out:
#                                             mean                  \
#                                    beer_servings spirit_servings
# continent country
# AF        Algeria                             25               0
#           Angola                             217              57
#           Benin                               34               4
#           Botswana                           173              35
#           Burkina Faso                        25               7
#           Burundi                             88               0
#           Cabo Verde                         144              56
#           Cameroon                           147               1
#           Central African Republic            17               2
#           Chad                                15               1
#           Comoros                              1               3
#           Congo                               76               1
# ...

# %% [markdown]
# ### Step 7. Print the median alcohol consumption per continent for every column

# %%
pd.pivot_table(drinks,index=['continent'], values=['beer_servings','spirit_servings','wine_servings','total_litres_of_pure_alcohol'],aggfunc=['median'])
# Out:
#                  median                                               \
#           beer_servings spirit_servings total_litres_of_pure_alcohol
# continent
# AF                 32.0             3.0                         2.30
# AS                 17.5            16.0                         1.20
# EU                219.0           122.0                        10.00
# OC                 52.5            37.0                         1.75
# SA                162.5           108.5                         6.85
#
#
#           wine_servings
# continent
# AF                  2.0
# AS                  1.0
# EU                128.0
# OC                  8.5
# SA                 12.0

# %% [markdown]
# ### Step 8. Print the mean, min and max values for spirit consumption.
# #### This time output a DataFrame

# %%
pd.pivot_table(drinks,index=['continent'],values=['spirit_servings'],aggfunc=['mean','max','min'])
# Out:
#                      mean             max             min
#           spirit_servings spirit_servings spirit_servings
# continent
# AF              16.339623             152               0
# AS              60.840909             326               0
# EU             132.555556             373               0
# OC              58.437500             254               0
# SA             114.750000             302              25
