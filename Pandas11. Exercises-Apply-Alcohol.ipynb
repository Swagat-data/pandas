# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Introduction:
#
# This time you will download a dataset from the UCI.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df=pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/Students_Alcohol_Consumption/student-mat.csv')

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.loc[:,'school':'guardian']
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 10      GP   F   15       U     GT3       T     4     4   teacher    health
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 14      GP   M   15       U     GT3       A     2     2     other     other
# 15      GP   F   16       U     GT3       T     4     4    health     other
# 16      GP   F   16       U     GT3       T     4     4  services  services
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 19      GP   M   16       U     LE3       T     4     3    health     other
# 20      GP   M   15       U     GT3       T     4     3   teacher     other
# 21      GP   M   15       U     GT3       T     4     4    health    health
# 22      GP   M   16       U     LE3       T     4     2   teacher     other
# 23      GP   M   16       U     LE3       T     2     2     other     other
# 24      GP   F   15       R     GT3       T     2     4  services    health
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 26      GP   M   15       U     GT3       T     2     2     other     other
# 27      GP   M   15       U     GT3       T     4     2    health  services
# 28      GP   M   16       U     LE3       A     3     4  services     other
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 365     MS   M   18       R     GT3       T     1     3   at_home     other
# 366     MS   M   18       U     LE3       T     4     4   teacher  services
# 367     MS   F   17       R     GT3       T     1     1     other  services
# 368     MS   F   18       U     GT3       T     2     3   at_home  services
# 369     MS   F   18       R     GT3       T     4     4     other   teacher
# 370     MS   F   19       U     LE3       T     3     2  services  services
# 371     MS   M   18       R     LE3       T     1     2   at_home  services
# 372     MS   F   17       U     GT3       T     2     2     other   at_home
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 374     MS   F   18       R     LE3       T     4     4     other     other
# 375     MS   F   18       R     GT3       T     1     1     other     other
# 376     MS   F   20       U     GT3       T     4     2    health     other
# 377     MS   F   18       R     LE3       T     4     4   teacher  services
# 378     MS   F   18       U     GT3       T     3     3     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 380     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 381     MS   M   18       R     GT3       T     2     1     other     other
# 382     MS   M   17       U     GT3       T     2     3     other  services
# 383     MS   M   19       R     GT3       T     1     1     other  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#          reason guardian
# 0        course   mother
# 1        course   father
# 2         other   mother
# 3          home   mother
# 4          home   father
# 5    reputation   mother
# 6          home   mother
# 7          home   mother
# 8          home   mother
# 9          home   mother
# 10   reputation   mother
# 11   reputation   father
# 12       course   father
# 13       course   mother
# 14         home    other
# 15         home   mother
# 16   reputation   mother
# 17   reputation   mother
# 18       course   mother
# 19         home   father
# 20   reputation   mother
# 21        other   father
# 22       course   mother
# 23   reputation   mother
# 24       course   mother
# 25         home   mother
# 26         home   mother
# 27        other   mother
# 28         home   mother
# 29         home   mother
# ..          ...      ...
# 365      course   mother
# 366       other   mother
# 367  reputation   mother
# 368      course   father
# 369       other   father
# 370        home    other
# 371       other   father
# 372        home   mother
# 373      course   mother
# 374  reputation   mother
# 375        home   mother
# 376      course    other
# 377      course   mother
# 378        home   mother
# 379  reputation   mother
# 380        home   father
# 381       other   mother
# 382        home   father
# 383       other   mother
# 384        home   father
# 385       other   mother
# 386  reputation   mother
# 387      course   mother
# 388      course   mother
# 389      course   mother
# 390      course    other
# 391      course   mother
# 392      course    other
# 393      course   mother
# 394      course   father
#
# [395 rows x 12 columns]

# %% [markdown]
# ### Step 5. Create a lambda function that capitalize strings.

# %%
df[['Mjob','Fjob']]
# Out:
#          Mjob      Fjob
# 0     at_home   teacher
# 1     at_home     other
# 2     at_home     other
# 3      health  services
# 4       other     other
# 5    services     other
# 6       other     other
# 7       other   teacher
# 8    services     other
# 9       other     other
# 10    teacher    health
# 11   services     other
# 12     health  services
# 13    teacher     other
# 14      other     other
# 15     health     other
# 16   services  services
# 17      other     other
# 18   services  services
# 19     health     other
# 20    teacher     other
# 21     health    health
# 22    teacher     other
# 23      other     other
# 24   services    health
# 25   services  services
# 26      other     other
# 27     health  services
# 28   services     other
# 29    teacher   teacher
# ..        ...       ...
# 365   at_home     other
# 366   teacher  services
# 367     other  services
# 368   at_home  services
# 369     other   teacher
# 370  services  services
# 371   at_home  services
# 372     other   at_home
# 373     other     other
# 374     other     other
# 375     other     other
# 376    health     other
# 377   teacher  services
# 378     other     other
# 379   at_home     other
# 380   teacher   teacher
# 381     other     other
# 382     other  services
# 383     other  services
# 384     other     other
# 385   at_home     other
# 386   teacher   at_home
# 387  services     other
# 388   teacher  services
# 389     other     other
# 390  services  services
# 391  services  services
# 392     other     other
# 393  services     other
# 394     other   at_home
#
# [395 rows x 2 columns]

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
LA=lambda x: x.upper() 
df['Mjob']=df['Mjob'].apply(LA)
df['Fjob']=df['Fjob'].apply(LA)
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME   TEACHER  ...
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME     OTHER  ...
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME     OTHER  ...
# 3     GP   F   15       U     GT3       T     4     2   HEALTH  SERVICES  ...
# 4     GP   F   16       U     GT3       T     3     3    OTHER     OTHER  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 6. Print the last elements of the data set.

# %%
L=df.tail(1)
L.iloc[-1:,-1]
# Out:
# 394    9
# Name: G3, dtype: int64

# %% [markdown]
# ### Step 7. Did you notice the original dataframe is still lowercase? Why is that? Fix it and capitalize Mjob and Fjob.

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  AT_HOME   TEACHER  ...
# 1     GP   F   17       U     GT3       T     1     1  AT_HOME     OTHER  ...
# 2     GP   F   15       U     LE3       T     1     1  AT_HOME     OTHER  ...
# 3     GP   F   15       U     GT3       T     4     2   HEALTH  SERVICES  ...
# 4     GP   F   16       U     GT3       T     3     3    OTHER     OTHER  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
LA=lambda x:x.upper()

# %%
df=df.apply(LA)

# %% [markdown]
# ### Step 8. Create a function called majority that return a boolean value to a new column called legal_drinker (Consider majority as older than 17 years old)

# %%
def majority(m):
    if m > 17:
        return "True"
    else:
        return "False"

# %%
df['legal_drinker']=df['age'].apply(majority)

# %%
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   AT_HOME   TEACHER
# 1       GP   F   17       U     GT3       T     1     1   AT_HOME     OTHER
# 2       GP   F   15       U     LE3       T     1     1   AT_HOME     OTHER
# 3       GP   F   15       U     GT3       T     4     2    HEALTH  SERVICES
# 4       GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# 5       GP   M   16       U     LE3       T     4     3  SERVICES     OTHER
# 6       GP   M   16       U     LE3       T     2     2     OTHER     OTHER
# 7       GP   F   17       U     GT3       A     4     4     OTHER   TEACHER
# 8       GP   M   15       U     LE3       A     3     2  SERVICES     OTHER
# 9       GP   M   15       U     GT3       T     3     4     OTHER     OTHER
# 10      GP   F   15       U     GT3       T     4     4   TEACHER    HEALTH
# 11      GP   F   15       U     GT3       T     2     1  SERVICES     OTHER
# 12      GP   M   15       U     LE3       T     4     4    HEALTH  SERVICES
# 13      GP   M   15       U     GT3       T     4     3   TEACHER     OTHER
# 14      GP   M   15       U     GT3       A     2     2     OTHER     OTHER
# 15      GP   F   16       U     GT3       T     4     4    HEALTH     OTHER
# 16      GP   F   16       U     GT3       T     4     4  SERVICES  SERVICES
# 17      GP   F   16       U     GT3       T     3     3     OTHER     OTHER
# 18      GP   M   17       U     GT3       T     3     2  SERVICES  SERVICES
# 19      GP   M   16       U     LE3       T     4     3    HEALTH     OTHER
# 20      GP   M   15       U     GT3       T     4     3   TEACHER     OTHER
# 21      GP   M   15       U     GT3       T     4     4    HEALTH    HEALTH
# 22      GP   M   16       U     LE3       T     4     2   TEACHER     OTHER
# 23      GP   M   16       U     LE3       T     2     2     OTHER     OTHER
# 24      GP   F   15       R     GT3       T     2     4  SERVICES    HEALTH
# 25      GP   F   16       U     GT3       T     2     2  SERVICES  SERVICES
# 26      GP   M   15       U     GT3       T     2     2     OTHER     OTHER
# 27      GP   M   15       U     GT3       T     4     2    HEALTH  SERVICES
# 28      GP   M   16       U     LE3       A     3     4  SERVICES     OTHER
# 29      GP   M   16       U     GT3       T     4     4   TEACHER   TEACHER
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 365     MS   M   18       R     GT3       T     1     3   AT_HOME     OTHER
# 366     MS   M   18       U     LE3       T     4     4   TEACHER  SERVICES
# 367     MS   F   17       R     GT3       T     1     1     OTHER  SERVICES
# 368     MS   F   18       U     GT3       T     2     3   AT_HOME  SERVICES
# 369     MS   F   18       R     GT3       T     4     4     OTHER   TEACHER
# 370     MS   F   19       U     LE3       T     3     2  SERVICES  SERVICES
# 371     MS   M   18       R     LE3       T     1     2   AT_HOME  SERVICES
# 372     MS   F   17       U     GT3       T     2     2     OTHER   AT_HOME
# 373     MS   F   17       R     GT3       T     1     2     OTHER     OTHER
# 374     MS   F   18       R     LE3       T     4     4     OTHER     OTHER
# 375     MS   F   18       R     GT3       T     1     1     OTHER     OTHER
# 376     MS   F   20       U     GT3       T     4     2    HEALTH     OTHER
# 377     MS   F   18       R     LE3       T     4     4   TEACHER  SERVICES
# 378     MS   F   18       U     GT3       T     3     3     OTHER     OTHER
# 379     MS   F   17       R     GT3       T     3     1   AT_HOME     OTHER
# 380     MS   M   18       U     GT3       T     4     4   TEACHER   TEACHER
# 381     MS   M   18       R     GT3       T     2     1     OTHER     OTHER
# 382     MS   M   17       U     GT3       T     2     3     OTHER  SERVICES
# 383     MS   M   19       R     GT3       T     1     1     OTHER  SERVICES
# 384     MS   M   18       R     GT3       T     4     2     OTHER     OTHER
# 385     MS   F   18       R     GT3       T     2     2   AT_HOME     OTHER
# 386     MS   F   18       R     GT3       T     4     4   TEACHER   AT_HOME
# 387     MS   F   19       R     GT3       T     2     3  SERVICES     OTHER
# 388     MS   F   18       U     LE3       T     3     1   TEACHER  SERVICES
# 389     MS   F   18       U     GT3       T     1     1     OTHER     OTHER
# 390     MS   M   20       U     LE3       A     2     2  SERVICES  SERVICES
# 391     MS   M   17       U     LE3       T     3     1  SERVICES  SERVICES
# 392     MS   M   21       R     GT3       T     1     1     OTHER     OTHER
# 393     MS   M   18       R     LE3       T     3     2  SERVICES     OTHER
# 394     MS   M   19       U     LE3       T     1     1     OTHER   AT_HOME
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 legal_drinker
# 0    ...        3     4     1     1       3        6   5   6   6          True
# 1    ...        3     3     1     1       3        4   5   5   6         False
# 2    ...        3     2     2     3       3       10   7   8  10         False
# 3    ...        2     2     1     1       5        2  15  14  15         False
# 4    ...        3     2     1     2       5        4   6  10  10         False
# 5    ...        4     2     1     2       5       10  15  15  15         False
# 6    ...        4     4     1     1       3        0  12  12  11         False
# 7    ...        1     4     1     1       1        6   6   5   6         False
# 8    ...        2     2     1     1       1        0  16  18  19         False
# 9    ...        5     1     1     1       5        0  14  15  15         False
# 10   ...        3     3     1     2       2        0  10   8   9         False
# 11   ...        2     2     1     1       4        4  10  12  12         False
# 12   ...        3     3     1     3       5        2  14  14  14         False
# 13   ...        4     3     1     2       3        2  10  10  11         False
# 14   ...        5     2     1     1       3        0  14  16  16         False
# 15   ...        4     4     1     2       2        4  14  14  14         False
# 16   ...        2     3     1     2       2        6  13  14  14         False
# 17   ...        3     2     1     1       4        4   8  10  10         False
# 18   ...        5     5     2     4       5       16   6   5   5         False
# 19   ...        1     3     1     3       5        4   8  10  10         False
# 20   ...        4     1     1     1       1        0  13  14  15         False
# 21   ...        4     2     1     1       5        0  12  15  15         False
# 22   ...        5     1     1     3       5        2  15  15  16         False
# 23   ...        4     4     2     4       5        0  13  13  12         False
# 24   ...        3     2     1     1       5        2  10   9   8         False
# 25   ...        2     2     1     3       5       14   6   9   8         False
# 26   ...        2     2     1     2       5        2  12  12  11         False
# 27   ...        2     4     2     4       1        4  15  16  15         False
# 28   ...        3     3     1     1       5        4  11  11  11         False
# 29   ...        4     5     5     5       5       16  10  12  11         False
# ..   ...      ...   ...   ...   ...     ...      ...  ..  ..  ..           ...
# 365  ...        3     4     2     4       3        4  10  10  10          True
# 366  ...        2     2     2     2       5        0  13  13  13          True
# 367  ...        2     1     1     2       1        0   7   6   0         False
# 368  ...        2     3     1     2       4        0  11  10  10          True
# 369  ...        2     2     4     2       5       10  14  12  11          True
# 370  ...        2     2     1     1       3        4   7   7   9          True
# 371  ...        3     3     2     3       3        3  14  12  12          True
# 372  ...        4     3     1     1       3        8  13  11  11         False
# 373  ...        5     5     1     3       1       14   6   5   5         False
# 374  ...        4     4     1     1       1        0  19  18  19          True
# 375  ...        3     2     1     2       4        2   8   8  10          True
# 376  ...        4     3     1     1       3        4  15  14  15          True
# 377  ...        4     3     3     4       2        4   8   9  10          True
# 378  ...        1     3     1     2       1        0  15  15  15          True
# 379  ...        5     4     2     3       1       17  10  10  10         False
# 380  ...        2     4     1     4       2        4  15  14  14          True
# 381  ...        4     3     1     3       5        5   7   6   7          True
# 382  ...        4     3     1     1       3        2  11  11  10         False
# 383  ...        3     2     1     3       5        0   6   5   0          True
# 384  ...        4     3     4     3       3       14   6   5   5          True
# 385  ...        3     3     1     3       4        2  10   9  10          True
# 386  ...        4     3     2     2       5        7   6   5   6          True
# 387  ...        4     2     1     2       5        0   7   5   0          True
# 388  ...        3     4     1     1       1        0   7   9   8          True
# 389  ...        1     1     1     1       5        0   6   5   0          True
# 390  ...        5     4     4     5       4       11   9   9   9          True
# 391  ...        4     5     3     4       2        3  14  16  16         False
# 392  ...        5     3     3     3       3        3  10   8   7          True
# 393  ...        4     1     3     4       5        0  11  12  10          True
# 394  ...        2     3     3     3       5        5   8   9   9          True
#
# [395 rows x 34 columns]

# %% [markdown]
# ### Step 9. Multiply every number of the dataset by 10.
# ##### I know this makes no sense, don't forget it is just an exercise

# %%
df*10
# Out:
#                    school         sex  age     address  \
# 0    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  180  UUUUUUUUUU
# 1    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  170  UUUUUUUUUU
# 2    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 3    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 4    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 5    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 6    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 7    GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  170  UUUUUUUUUU
# 8    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 9    GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 10   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 11   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  UUUUUUUUUU
# 12   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 13   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 14   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 15   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 16   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 17   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 18   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  170  UUUUUUUUUU
# 19   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 20   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 21   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 22   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 23   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 24   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  150  RRRRRRRRRR
# 25   GPGPGPGPGPGPGPGPGPGP  FFFFFFFFFF  160  UUUUUUUUUU
# 26   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 27   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  150  UUUUUUUUUU
# 28   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# 29   GPGPGPGPGPGPGPGPGPGP  MMMMMMMMMM  160  UUUUUUUUUU
# ..                    ...         ...  ...         ...
# 365  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  RRRRRRRRRR
# 366  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  UUUUUUUUUU
# 367  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  170  RRRRRRRRRR
# 368  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  UUUUUUUUUU
# 369  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 370  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  190  UUUUUUUUUU
# 371  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  RRRRRRRRRR
# 372  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  170  UUUUUUUUUU
# 373  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  170  RRRRRRRRRR
# 374  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 375  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 376  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  200  UUUUUUUUUU
# 377  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 378  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  UUUUUUUUUU
# 379  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  170  RRRRRRRRRR
# 380  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  UUUUUUUUUU
# 381  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  RRRRRRRRRR
# 382  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  170  UUUUUUUUUU
# 383  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  190  RRRRRRRRRR
# 384  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  RRRRRRRRRR
# 385  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 386  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  RRRRRRRRRR
# 387  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  190  RRRRRRRRRR
# 388  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  UUUUUUUUUU
# 389  MSMSMSMSMSMSMSMSMSMS  FFFFFFFFFF  180  UUUUUUUUUU
# 390  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  200  UUUUUUUUUU
# 391  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  170  UUUUUUUUUU
# 392  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  210  RRRRRRRRRR
# 393  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  180  RRRRRRRRRR
# 394  MSMSMSMSMSMSMSMSMSMS  MMMMMMMMMM  190  UUUUUUUUUU
#
#                             famsize     Pstatus  Medu  Fedu  \
# 0    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  AAAAAAAAAA    40    40
# 1    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 2    LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    10    10
# 3    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    20
# 4    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    30
# 5    LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    30
# 6    LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    20    20
# 7    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  AAAAAAAAAA    40    40
# 8    LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  AAAAAAAAAA    30    20
# 9    GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    40
# 10   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 11   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    10
# 12   LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    40
# 13   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    30
# 14   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  AAAAAAAAAA    20    20
# 15   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 16   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 17   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    30
# 18   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    20
# 19   LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    30
# 20   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    30
# 21   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 22   LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    20
# 23   LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    20    20
# 24   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    40
# 25   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    20
# 26   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    20
# 27   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    20
# 28   LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  AAAAAAAAAA    30    40
# 29   GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# ..                              ...         ...   ...   ...
# 365  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    30
# 366  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    40
# 367  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 368  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    30
# 369  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 370  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    30    20
# 371  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    10    20
# 372  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    20
# 373  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    20
# 374  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    40
# 375  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 376  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    20
# 377  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    40    40
# 378  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    30
# 379  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    30    10
# 380  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 381  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    10
# 382  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    30
# 383  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 384  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    20
# 385  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    20
# 386  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    40    40
# 387  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    20    30
# 388  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    30    10
# 389  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 390  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  AAAAAAAAAA    20    20
# 391  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    30    10
# 392  GT3GT3GT3GT3GT3GT3GT3GT3GT3GT3  TTTTTTTTTT    10    10
# 393  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    30    20
# 394  LE3LE3LE3LE3LE3LE3LE3LE3LE3LE3  TTTTTTTTTT    10    10
#
#                                                   Mjob  \
# 0    AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 1    AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 2    AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 3    HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 4    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 5    SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 6    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 7    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 8    SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 9    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 10   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 11   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 12   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 13   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 14   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 15   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 16   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 17   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 18   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 19   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 20   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 21   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 22   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 23   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 24   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 25   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 26   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 27   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 28   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 29   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# ..                                                 ...
# 365  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 366  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 367  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 368  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 369  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 370  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 371  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 372  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 373  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 374  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 375  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 376  HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...
# 377  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 378  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 379  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 380  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 381  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 382  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 383  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 384  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 385  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...
# 386  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 387  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 388  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...
# 389  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 390  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 391  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 392  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
# 393  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...
# 394  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...
#
#                                                   Fjob  ... freetime goout  \
# 0    TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...  ...       30    40
# 1    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    30
# 2    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    20
# 3    SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    20
# 4    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    20
# 5    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    20
# 6    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    40
# 7    TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...  ...       10    40
# 8    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       20    20
# 9    OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    10
# 10   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...  ...       30    30
# 11   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       20    20
# 12   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       30    30
# 13   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    30
# 14   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    20
# 15   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    40
# 16   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    30
# 17   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    20
# 18   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       50    50
# 19   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       10    30
# 20   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    10
# 21   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...  ...       40    20
# 22   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    10
# 23   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    40
# 24   HEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEALTHHEAL...  ...       30    20
# 25   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    20
# 26   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       20    20
# 27   SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    40
# 28   OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    30
# 29   TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...  ...       40    50
# ..                                                 ...  ...      ...   ...
# 365  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    40
# 366  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    20
# 367  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    10
# 368  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    30
# 369  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...  ...       20    20
# 370  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       20    20
# 371  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       30    30
# 372  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...  ...       40    30
# 373  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    50
# 374  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    40
# 375  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    20
# 376  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    30
# 377  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       40    30
# 378  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       10    30
# 379  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    40
# 380  TEACHERTEACHERTEACHERTEACHERTEACHERTEACHERTEAC...  ...       20    40
# 381  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    30
# 382  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       40    30
# 383  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       30    20
# 384  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    30
# 385  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       30    30
# 386  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...  ...       40    30
# 387  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    20
# 388  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       30    40
# 389  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       10    10
# 390  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       50    40
# 391  SERVICESSERVICESSERVICESSERVICESSERVICESSERVIC...  ...       40    50
# 392  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       50    30
# 393  OTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHEROTHERO...  ...       40    10
# 394  AT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_HOMEAT_H...  ...       20    30
#
#      Dalc  Walc  health absences   G1   G2   G3  \
# 0      10    10      30       60   50   60   60
# 1      10    10      30       40   50   50   60
# 2      20    30      30      100   70   80  100
# 3      10    10      50       20  150  140  150
# 4      10    20      50       40   60  100  100
# 5      10    20      50      100  150  150  150
# 6      10    10      30        0  120  120  110
# 7      10    10      10       60   60   50   60
# 8      10    10      10        0  160  180  190
# 9      10    10      50        0  140  150  150
# 10     10    20      20        0  100   80   90
# 11     10    10      40       40  100  120  120
# 12     10    30      50       20  140  140  140
# 13     10    20      30       20  100  100  110
# 14     10    10      30        0  140  160  160
# 15     10    20      20       40  140  140  140
# 16     10    20      20       60  130  140  140
# 17     10    10      40       40   80  100  100
# 18     20    40      50      160   60   50   50
# 19     10    30      50       40   80  100  100
# 20     10    10      10        0  130  140  150
# 21     10    10      50        0  120  150  150
# 22     10    30      50       20  150  150  160
# 23     20    40      50        0  130  130  120
# 24     10    10      50       20  100   90   80
# 25     10    30      50      140   60   90   80
# 26     10    20      50       20  120  120  110
# 27     20    40      10       40  150  160  150
# 28     10    10      50       40  110  110  110
# 29     50    50      50      160  100  120  110
# ..    ...   ...     ...      ...  ...  ...  ...
# 365    20    40      30       40  100  100  100
# 366    20    20      50        0  130  130  130
# 367    10    20      10        0   70   60    0
# 368    10    20      40        0  110  100  100
# 369    40    20      50      100  140  120  110
# 370    10    10      30       40   70   70   90
# 371    20    30      30       30  140  120  120
# 372    10    10      30       80  130  110  110
# 373    10    30      10      140   60   50   50
# 374    10    10      10        0  190  180  190
# 375    10    20      40       20   80   80  100
# 376    10    10      30       40  150  140  150
# 377    30    40      20       40   80   90  100
# 378    10    20      10        0  150  150  150
# 379    20    30      10      170  100  100  100
# 380    10    40      20       40  150  140  140
# 381    10    30      50       50   70   60   70
# 382    10    10      30       20  110  110  100
# 383    10    30      50        0   60   50    0
# 384    40    30      30      140   60   50   50
# 385    10    30      40       20  100   90  100
# 386    20    20      50       70   60   50   60
# 387    10    20      50        0   70   50    0
# 388    10    10      10        0   70   90   80
# 389    10    10      50        0   60   50    0
# 390    40    50      40      110   90   90   90
# 391    30    40      20       30  140  160  160
# 392    30    30      30       30  100   80   70
# 393    30    40      50        0  110  120  100
# 394    30    30      50       50   80   90   90
#
#                                          legal_drinker
# 0             TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 1    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 2    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 3    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 4    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 5    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 6    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 7    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 8    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 9    FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 10   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 11   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 12   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 13   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 14   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 15   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 16   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 17   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 18   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 19   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 20   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 21   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 22   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 23   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 24   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 25   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 26   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 27   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 28   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 29   FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# ..                                                 ...
# 365           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 366           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 367  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 368           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 369           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 370           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 371           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 372  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 373  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 374           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 375           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 376           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 377           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 378           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 379  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 380           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 381           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 382  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 383           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 384           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 385           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 386           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 387           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 388           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 389           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 390           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 391  FalseFalseFalseFalseFalseFalseFalseFalseFalseF...
# 392           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 393           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
# 394           TrueTrueTrueTrueTrueTrueTrueTrueTrueTrue
#
# [395 rows x 34 columns]
